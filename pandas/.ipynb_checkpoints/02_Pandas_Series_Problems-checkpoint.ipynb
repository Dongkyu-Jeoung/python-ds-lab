# %% [markdown]
# # 🧪 Pandas Series 실습 문제 (6/12)

# %%
# 공통 라이브러리 불러오기
import pandas as pd
import numpy as np

# %% [markdown]
# ## 문제 1-1
#
# 다음 나이 데이터를 리스트로 Series로 생성하세요.
#
# ```python
# [25, 34, 19, 45, 60]
# ```
#
# 변수명은 `age`로 작성하세요.

# %%
age = pd.Series(np.array([25, 34, 19, 45, 60]))
age
# Out:
# 0    25
# 1    34
# 2    19
# 3    45
# 4    60
# dtype: int64

# %% [markdown]
# ## 문제 1-2
#
# 다음 계절 데이터를 Series로 생성하세요.
#
# 값:
#
# ```python
# ['봄', '여름', '가을', '겨울']
# ```
#
# 인덱스:
#
# ```python
# ['spring', 'summer', 'fall', 'winter']
# ```
#
# 변수명은 `season`으로 작성하세요.

# %%
# 문제 1-2 코드 작성
season = pd.Series(['봄', '여름', '가을', '겨울'], index = ['spring', 'summer', 'fall', 'winter'])
season
# Out:
# spring     봄
# summer    여름
# fall      가을
# winter    겨울
# dtype: object

# %% [markdown]
# ## 문제 1-3
#
# 다음 딕셔너리를 이용하여 Series를 생성하세요.
#
# ```python
# {'국어': 85, '영어': 92, '수학': 78, '과학': 90}
# ```
#
# 변수명은 `score`로 작성하세요.

# %%
# 문제 1-3 코드 작성
dict = {'국어' : 85, '영어' : 92, '수학' : 78, '과학' : 90}
score = pd.Series(dict)
score
# Out:
# 국어    85
# 영어    92
# 수학    78
# 과학    90
# dtype: int64

# %% [markdown]
# ## 문제 1-4
#
# 다음 서울 월평균 기온 데이터를 Series로 생성한 뒤, 인덱스를 1월부터 12월까지로 교체하세요.
#
# 기온 데이터:
#
# ```python
# [-0.8, -0.1, 7.7, 13.8, 18.0, 22.4, 25.9, 25.3, 21.0, 14.0, 9.6, -1.4]
# ```
#
# 인덱스:
#
# ```python
# ['1월','2월','3월','4월','5월','6월','7월','8월','9월','10월','11월','12월']
# ```
#
# 변수명은 `temp`로 작성하세요.

# %%
# 문제 1-4 코드 작성
temp = pd.Series([-0.8, -0.1, 7.7, 13.8, 18.0, 22.4, 25.9, 25.3, 21.0, 14.0, 9.6, -1.4])
temp.index = ['1월','2월','3월','4월','5월','6월','7월','8월','9월','10월','11월','12월']
temp
# Out:
# 1월     -0.8
# 2월     -0.1
# 3월      7.7
# 4월     13.8
# 5월     18.0
# 6월     22.4
# 7월     25.9
# 8월     25.3
# 9월     21.0
# 10월    14.0
# 11월     9.6
# 12월    -1.4
# dtype: float64

# %% [markdown]
# ---
#
# 아래 `temp` Series를 이용하여 문제를 해결하세요.

# %%
temp = pd.Series(
    [-0.8, -0.1, 7.7, 13.8, 18.0, 22.4, 25.9, 25.3, 21.0, 14.0, 9.6, -1.4],
    index=['1월','2월','3월','4월','5월','6월','7월','8월','9월','10월','11월','12월']
)

temp
# Out:
# 1월     -0.8
# 2월     -0.1
# 3월      7.7
# 4월     13.8
# 5월     18.0
# 6월     22.4
# 7월     25.9
# 8월     25.3
# 9월     21.0
# 10월    14.0
# 11월     9.6
# 12월    -1.4
# dtype: float64

# %% [markdown]
# ## 문제 2-1
#
# `temp`의 원소 개수를 `size`로 확인하세요.

# %%
# 문제 2-1 코드 작성
temp.size
# Out:
# 12

# %% [markdown]
# ## 문제 2-2
#
# `temp`의 원소 개수를 `len()`으로 확인하세요.

# %%
# 문제 2-2 코드 작성
len(temp)
# Out:
# 12

# %% [markdown]
# ## 문제 2-3
#
# `temp`의 배열 형태를 확인하세요.

# %%
# 문제 2-3 코드 작성
temp.shape
# Out:
# (12,)

# %% [markdown]
# ## 문제 2-4
#
# `temp`의 데이터 타입을 확인하세요.

# %%
# 문제 2-4 코드 작성
temp.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## 문제 2-5
#
# `temp`의 인덱스를 리스트로 출력하세요.

# %%
# 문제 2-5 코드 작성
temp.index
# Out:
# Index(['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월',
#        '12월'],
#       dtype='object')

# %% [markdown]
# ## 문제 2-6
#
# `temp`의 값 중 앞에서 5개만 출력하세요.

# %%
# 문제 2-6 코드 작성
temp.head()
# Out:
# 1월    -0.8
# 2월    -0.1
# 3월     7.7
# 4월    13.8
# 5월    18.0
# dtype: float64

# %% [markdown]
# ## 문제 2-7
#
# `describe()`를 사용하여 `temp`의 요약 통계를 확인하세요.
# 소수점 둘째 자리까지 반올림하세요.

# %%
# 문제 2-7 코드 작성
temp.describe().round(2)
# Out:
# count    12.00
# mean     12.95
# std      10.03
# min      -1.40
# 25%       5.75
# 50%      13.90
# 75%      21.35
# max      25.90
# dtype: float64

# %% [markdown]
# ---
#
# 아래 `temp` Series를 이용하여 문제를 해결하세요.

# %%
temp = pd.Series(
    [-0.8, -0.1, 7.7, 13.8, 18.0, 22.4, 25.9, 25.3, 21.0, 14.0, 9.6, -1.4],
    index=['1월','2월','3월','4월','5월','6월','7월','8월','9월','10월','11월','12월']
)

temp
# Out:
# 1월     -0.8
# 2월     -0.1
# 3월      7.7
# 4월     13.8
# 5월     18.0
# 6월     22.4
# 7월     25.9
# 8월     25.3
# 9월     21.0
# 10월    14.0
# 11월     9.6
# 12월    -1.4
# dtype: float64

# %% [markdown]
# ## 문제 3-1
#
# `iloc`를 사용하여 3번째 위치의 값을 출력하세요.

# %%
# 문제 3-1 코드 작성
temp.iloc[2]
# Out:
# np.float64(7.7)

# %% [markdown]
# ## 문제 3-2
#
# `loc`를 사용하여 `'3월'`의 값을 출력하세요.

# %%
# 문제 3-2 코드 작성
temp.loc['3월']
# Out:
# np.float64(7.7)

# %% [markdown]
# ## 문제 3-3
#
# `iloc`를 사용하여 4월, 6월, 8월 위치의 값을 출력하세요.

# %%
# 문제 3-3 코드 작성
temp.iloc[3:8:2]
# Out:
# 4월    13.8
# 6월    22.4
# 8월    25.3
# dtype: float64

# %% [markdown]
# ## 문제 3-4
#
# `loc`를 사용하여 `'4월'`, `'6월'`, `'8월'`의 값을 출력하세요.

# %%
# 문제 3-4 코드 작성
temp.loc['4월':'8월':2]
# Out:
# 4월    13.8
# 6월    22.4
# 8월    25.3
# dtype: float64

# %% [markdown]
# ## 문제 3-5
#
# `iloc` 슬라이싱으로 6월부터 8월까지의 값을 출력하세요.

# %%
# 문제 3-5 코드 작성
temp.iloc[5:8]
# Out:
# 6월    22.4
# 7월    25.9
# 8월    25.3
# dtype: float64

# %% [markdown]
# ## 문제 3-6
#
# `loc` 슬라이싱으로 `'6월'`부터 `'9월'`까지의 값을 출력하세요.

# %%
# 문제 3-6 코드 작성
temp.loc['6월':'9월']
# Out:
# 6월    22.4
# 7월    25.9
# 8월    25.3
# 9월    21.0
# dtype: float64

# %% [markdown]
# ## 문제 3-7
#
# `iloc`를 사용하여 마지막 원소를 출력하세요.

# %%
# 문제 3-7 코드 작성
temp.iloc[-1]
# Out:
# np.float64(-1.4)

# %% [markdown]
# ## 문제 3-8
#
# `iloc`를 사용하여 마지막 3개 원소를 출력하세요.

# %%
# 문제 3-8 코드 작성
temp.iloc[-3:]
# Out:
# 10월    14.0
# 11월     9.6
# 12월    -1.4
# dtype: float64

# %% [markdown]
# ---
#
# 아래 `temp` Series를 이용하여 문제를 해결하세요.

# %%
temp = pd.Series(
    [-0.8, -0.1, 7.7, 13.8, 18.0, 22.4, 25.9, 25.3, 21.0, 14.0, 9.6, -1.4],
    index=['1월','2월','3월','4월','5월','6월','7월','8월','9월','10월','11월','12월']
)

temp
# Out:
# 1월     -0.8
# 2월     -0.1
# 3월      7.7
# 4월     13.8
# 5월     18.0
# 6월     22.4
# 7월     25.9
# 8월     25.3
# 9월     21.0
# 10월    14.0
# 11월     9.6
# 12월    -1.4
# dtype: float64

# %% [markdown]
# ## 문제 4-1
#
# 기온이 15도 이상인 월만 출력하세요.

# %%
# 문제 4-1 코드 작성
temp[temp >= 15]
# Out:
# 5월    18.0
# 6월    22.4
# 7월    25.9
# 8월    25.3
# 9월    21.0
# dtype: float64

# %% [markdown]
# ## 문제 4-2
#
# 기온이 15도 이상이고 25도 미만인 월만 출력하세요.

# %%
# 문제 4-2 코드 작성
temp[(temp >= 15) & (temp < 25)]
# Out:
# 5월    18.0
# 6월    22.4
# 9월    21.0
# dtype: float64

# %% [markdown]
# ## 문제 4-3
#
# 기온이 5도 미만이거나 25도 이상인 월만 출력하세요.

# %%
# 문제 4-3 코드 작성
temp[(temp >= 25) | (temp < 5)]
# Out:
# 1월     -0.8
# 2월     -0.1
# 7월     25.9
# 8월     25.3
# 12월    -1.4
# dtype: float64

# %% [markdown]
# ## 문제 4-4
#
# 기온이 15도 이상인 월 이름만 리스트로 출력하세요.

# %%
# 문제 4-4 코드 작성
temp[temp >= 15].index
# Out:
# Index(['5월', '6월', '7월', '8월', '9월'], dtype='object')

# %% [markdown]
# ## 문제 4-5
#
# `where()`를 사용하여 15도 이상인 값만 남기고 나머지는 `NaN`으로 출력하세요.

# %%
# 문제 4-5 코드 작성
temp.where(temp >= 15)
# Out:
# 1월      NaN
# 2월      NaN
# 3월      NaN
# 4월      NaN
# 5월     18.0
# 6월     22.4
# 7월     25.9
# 8월     25.3
# 9월     21.0
# 10월     NaN
# 11월     NaN
# 12월     NaN
# dtype: float64

# %% [markdown]
# ## 문제 4-6
#
# `where()`와 `dropna()`를 함께 사용하여 15도 이상인 값만 출력하세요.

# %%
# 문제 4-6 코드 작성
temp.where(temp >= 15).dropna()
# Out:
# 5월    18.0
# 6월    22.4
# 7월    25.9
# 8월    25.3
# 9월    21.0
# dtype: float64

# %% [markdown]
# ---
# 아래 `temp` Series를 이용하여 문제를 해결하세요.

# %%
temp = pd.Series(
    [-0.8, -0.1, 7.7, 13.8, 18.0, 22.4, 25.9, 25.3, 21.0, 14.0, 9.6, -1.4],
    index=['1월','2월','3월','4월','5월','6월','7월','8월','9월','10월','11월','12월']
)

temp
# Out:
# 1월     -0.8
# 2월     -0.1
# 3월      7.7
# 4월     13.8
# 5월     18.0
# 6월     22.4
# 7월     25.9
# 8월     25.3
# 9월     21.0
# 10월    14.0
# 11월     9.6
# 12월    -1.4
# dtype: float64

# %% [markdown]
# ## 문제 5-1
#
# 섭씨 기온을 화씨로 변환한 뒤, 처음 3개만 출력하세요.
#
# 공식: `화씨 = 섭씨 * 9 / 5 + 32`

# %%
# 문제 5-1 코드 작성
(temp * 9 / 5 + 32).head(3)
# Out:
# 1월    30.56
# 2월    31.82
# 3월    45.86
# dtype: float64

# %% [markdown]
# ## 문제 5-2
#
# `temp`에서 1.5를 뺀 값을 `yesterday` 변수에 저장하세요.

# %%
# 문제 5-2 코드 작성
yesterday = temp - 1.5
yesterday
# Out:
# 1월     -2.3
# 2월     -1.6
# 3월      6.2
# 4월     12.3
# 5월     16.5
# 6월     20.9
# 7월     24.4
# 8월     23.8
# 9월     19.5
# 10월    12.5
# 11월     8.1
# 12월    -2.9
# dtype: float64

# %% [markdown]
# ## 문제 5-3
#
# `temp`와 `yesterday`의 차이를 구하여 처음 3개만 출력하세요.

# %%
# 문제 5-3 코드 작성
(temp - yesterday).head(3)
# Out:
# 1월    1.5
# 2월    1.5
# 3월    1.5
# dtype: float64

# %% [markdown]
# ## 문제 5-4
#
# `temp`의 합계를 출력하세요.

# %%
# 문제 5-4 코드 작성
temp.sum()
# Out:
# np.float64(155.39999999999998)

# %% [markdown]
# ## 문제 5-5
#
# `temp`의 평균을 출력하세요.

# %%
# 문제 5-5 코드 작성
temp.mean()
# Out:
# np.float64(12.949999999999998)

# %% [markdown]
# ## 문제 5-6
#
# `temp`의 중앙값을 출력하세요.

# %%
# 문제 5-6 코드 작성
temp.median()
# Out:
# 13.9

# %% [markdown]
# ## 문제 5-7
#
# 최고 기온과 최고 기온이 나타난 월을 출력하세요.

# %%
# 문제 5-7 코드 작성
print(f"최고 기온 : {temp.max()}, 월 : {temp.idxmax()}")
# Out:
# 최고 기온 : 25.9, 월 : 7월

# %% [markdown]
# ## 문제 5-8
#
# 최저 기온과 최저 기온이 나타난 월을 출력하세요.

# %%
# 문제 5-8 코드 작성
print(f"최고 기온 : {temp.min()}, 월 : {temp.idxmin()}")
# Out:
# 최고 기온 : -1.4, 월 : 12월

# %% [markdown]
# ## 문제 5-9
#
# `temp`의 표준편차를 출력하세요.

# %%
# 문제 5-9 코드 작성
temp.std()
# Out:
# 10.026011624315478

# %% [markdown]
# ## 문제 5-10
#
# 6월~8월의 여름 평균 기온을 구하세요.

# %%
# 문제 5-10 코드 작성
temp.loc['6월':'10월'].mean()
# Out:
# np.float64(21.72)

# %% [markdown]
# ## 문제 5-11
#
# 12월, 1월, 2월의 겨울 평균 기온을 구하세요.

# %%
# 문제 5-11 코드 작성
temp[['12월', '1월', '2월']].mean()
# Out:
# np.float64(-0.7666666666666667)

# %% [markdown]
# ## 문제 5-12
#
# 여름 평균 기온과 겨울 평균 기온의 차이를 구하세요.

# %%
# 문제 5-12 코드 작성
summer_mean = temp.loc['6월':'8월'].mean()
winter_mean = temp[['12월', '1월', '2월']].mean()
summer_mean - winter_mean
# Out:
# np.float64(25.299999999999997)

# %% [markdown]
# ---
#
# 아래 `score` Series를 이용하여 문제를 해결하세요.

# %%
score = pd.Series([75, 80, 90, 60],
                  index=['국어', '영어', '수학', '사회'])

score
# Out:
# 국어    75
# 영어    80
# 수학    90
# 사회    60
# dtype: int64

# %% [markdown]
# ## 문제 6-1
#
# `iloc`를 사용하여 국어 점수를 85점으로 수정하세요.

# %%
# 문제 6-1 코드 작성
score.iloc[0] = 85
score
# Out:
# 국어    85
# 영어    80
# 수학    90
# 사회    60
# dtype: int64

# %% [markdown]
# ## 문제 6-2
#
# `loc`를 사용하여 사회 점수를 65점으로 수정하세요.

# %%
# 문제 6-2 코드 작성
score.loc['사회'] = 65
score
# Out:
# 국어    85
# 영어    80
# 수학    90
# 사회    65
# dtype: int64

# %% [markdown]
# ## 문제 6-3
#
# 영어 점수와 수학 점수를 각각 70점, 80점으로 수정하세요.

# %%
# 문제 6-3 코드 작성
score.loc[['영어', '수학']] = [70, 80]
score
# Out:
# 국어    85
# 영어    70
# 수학    80
# 사회    65
# dtype: int64

# %% [markdown]
# ## 문제 6-4
#
# 새 과목 `'체육'`을 추가하고 점수를 95점으로 입력하세요.

# %%
# 문제 6-4 코드 작성
score['체육'] = 95
score
# Out:
# 국어    85
# 영어    70
# 수학    80
# 사회    65
# 체육    95
# dtype: int64

# %% [markdown]
# ## 문제 6-5
#
# `drop()`을 사용하여 `'체육'` 데이터를 삭제하세요. 삭제 결과가 반영되도록 재할당하세요.

# %%
# 문제 6-5 코드 작성
score = score.drop('체육')
score
# Out:
# 국어    85
# 영어    70
# 수학    80
# 사회    65
# dtype: int64

# %% [markdown]
# ## 문제 6-6
#
# `score_ref = score`를 사용하여 참조 복사를 만든 뒤, `score_ref`의 첫 번째 값을 999로 수정하세요. 원본 `score`도 바뀌는지 확인하세요.

# %%
# 문제 6-6 코드 작성
score_ref = score
score_ref.iloc[0] = 999
print(score_ref, score, sep='\n')
# Out:
# 국어    999
# 영어     70
# 수학     80
# 사회     65
# dtype: int64
# 국어    999
# 영어     70
# 수학     80
# 사회     65
# dtype: int64

# %% [markdown]
# ## 문제 6-7
#
# `score_copy = score.copy()`를 사용하여 깊은 복사를 만든 뒤, `score_copy`의 첫 번째 값을 0으로 수정하세요. 원본 `score`가 유지되는지 확인하세요.

# %%
# 문제 6-7 코드 작성
score_copy = score.copy()
score_copy.iloc[0] = 0
print(score_copy, score, sep='\n')
# Out:
# 국어     0
# 영어    70
# 수학    80
# 사회    65
# dtype: int64
# 국어    999
# 영어     70
# 수학     80
# 사회     65
# dtype: int64
